# %%
import pandas as pd
import numpy as np

df = pd.read_csv("bar.csv")
df.head()
# Out:
#    decile1b  decile3  ID  decile1  sex  race  cluster  lsat  ugpa  zfygpa  \
# 0      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
# 1       5.0      4.0   3      5.0  1.0   7.0      2.0  29.0   3.5   -0.11
# 2       3.0      2.0  36      3.0  2.0   7.0      3.0  36.0   3.5   -0.64
# 3       7.0      4.0  52      7.0  2.0   7.0      3.0  39.0   3.5    0.34
# 4       9.0      8.0  55      9.0  2.0   7.0      4.0  48.0   3.5    1.02
#
#    ...  hisp pass_bar                bar bar_passed  tier   index6040  \
# 0  ...     0        1  a Passed 1st time       True   4.0  886.842082
# 1  ...     0        1  a Passed 1st time       True   2.0  649.999987
# 2  ...     0        1  a Passed 1st time       True   3.0  760.526298
# 3  ...     0        1  a Passed 1st time       True   3.0  807.894717
# 4  ...     0        1  a Passed 1st time       True   5.0  949.999974
#
#      indxgrp   indxgrp2  dnn_bar_pass_prediction  gpa
# ...

# %%
#техническая информацию о датасете
type(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22407 entries, 0 to 22406
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   decile1b                 20803 non-null  float64
#  1   decile3                  20803 non-null  float64
#  2   ID                       22407 non-null  int64
#  3   decile1                  21315 non-null  float64
#  4   sex                      22402 non-null  float64
#  5   race                     22391 non-null  float64
#  6   cluster                  22311 non-null  float64
#  7   lsat                     22407 non-null  float64
#  8   ugpa                     22407 non-null  float64
#  9   zfygpa                   21423 non-null  float64
#  10  DOB_yr                   22357 non-null  float64
#  11  grad                     22404 non-null  object
#  12  zgpa                     21118 non-null  float64
# ...

# %%
#Номинальные данные - это определение принадлежности объекта (наблюдения) к тому или иному классу (Например номер больницы)
df.lsat
# Out:
# 0        44.0
# 1        29.0
# 2        36.0
# 3        39.0
# 4        48.0
#          ...
# 22402    26.5
# 22403    19.7
# 22404    36.0
# 22405    44.0
# 22406    29.5
# Name: lsat, Length: 22407, dtype: float64

# %%
# категориальные данные - данные с ограниченным числом уникальных значений или категорий
df.sex.unique()
# Out:
# array([ 1.,  2., nan])

# %%
# непрерывные данные - это данные, которые могут принимать любые значения в некотором интервале
df.cluster.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  6.,  5., nan])

# %%
# статистические характеристики - описываются особенности совокупности данных, полученных с помощью наблюдений
df.describe(include = "all")
# Out:
#             decile1b       decile3            ID       decile1           sex  \
# count   20803.000000  20803.000000  22407.000000  21315.000000  22402.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        5.528481      5.525934  13768.253537      5.708234      1.561378
# std         2.854800      2.851286   7929.063192      2.783098      0.496229
# min         1.000000      1.000000      2.000000      1.000000      1.000000
# 25%         3.000000      3.000000   6926.500000      3.000000      1.000000
# 50%         6.000000      6.000000  13772.000000      6.000000      2.000000
# 75%         8.000000      8.000000  20628.500000      8.000000      2.000000
# max        10.000000     10.000000  27477.000000     10.000000      2.000000
#
# ...

# %%
#Узнать есть ли пустые значения
df.isnull().value_counts()
# Out:
# decile1b  decile3  ID     decile1  sex    race   cluster  lsat   ugpa   zfygpa  DOB_yr  grad   zgpa   bar1   bar1_yr  bar2   bar2_yr  fulltime  fam_inc  age    gender  parttime  male   race1  race2  Dropout  other  asian  black  hisp   pass_bar  bar    bar_passed  tier   index6040  indxgrp  indxgrp2  dnn_bar_pass_prediction  gpa
# False     False    False  False    False  False  False    False  False  False   False   False  False  False  False    False  False    False     False    False  False   False     False  False  False  False    False  False  False  False  False     False  False       False  False      False    False     False                    False    20427
# ...

# %%
# Статистические характеристики числовых полей
# Максимальное
groups = df.groupby(["indxgrp"])
max(groups.size())
# Out:
# 15272

# %%
#Минимальное 
groups = df.groupby(["indxgrp"])
min(groups.size())
# Out:
# 39

# %%
#Среднее
df.groupby(["indxgrp2"])[["index6040"]].mean()
# Out:
#               index6040
# indxgrp2
# a under 400  367.827255
# b 400-460    435.752746
# c 460-520    493.589800
# d 520-580    553.557857
# e 580-640    614.113616
# f 640-700    672.523822
# g 700-760    730.285254
# h 760-820    789.233161
# i 820+       875.800096

# %%
#Медиана
df.groupby(["sex"])[["zfygpa","decile1"]].median()
# Out:
#      zfygpa  decile1
# sex
# 1.0    0.02      6.0
# 2.0    0.12      6.0

# %%
# Выполнить срезы набора данны
#по именам полей
df.loc[1:3, "sex" ]
# Out:
# 1    1.0
# 2    2.0
# 3    2.0
# Name: sex, dtype: float64

# %%
# Выполнить срезы набора данны
# по индексам
df.iloc[0:2, 2:4]
# Out:
#    ID  decile1
# 0   2     10.0
# 1   3      5.0

# %%
# Выполнить выбороки с фильтрацией по значниям полей (равенство, неравенство, частичный фильтр строк с помощью лямбда-функции)
df.iloc[lambda x: x.index % 2 == 0, [False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False, True, False, False]]
# Out:
#        decile3     ID  decile1  lsat  ugpa  zfygpa bar1  bar1_yr bar2   age  \
# 0         10.0      2     10.0  44.0   3.5    1.33    P      7.0    P -62.0
# 2          2.0     36      3.0  36.0   3.5   -0.64    P      7.0    P -58.0
# 4          8.0     55      9.0  48.0   3.5    1.02    P      7.0    P -61.0
# 6          7.0     74      9.0  34.0   3.5    0.96    P      7.0    P -62.0
# 8          2.0    109      4.0  40.0   3.5   -0.44    P      7.0    P -61.0
# ...        ...    ...      ...   ...   ...     ...  ...      ...  ...   ...
# 22398      4.0   5363      6.0  41.0   1.8    0.21    P      7.0    P -43.0
# 22400      6.0   7260      9.0  31.0   1.8    0.95    F      2.0    F -53.0
# 22402      1.0  10695      3.0  26.5   1.8   -0.58    F      2.0    F -62.0
# 22404      8.0  24704      7.0  36.0   1.8    0.41    P      7.0    P -59.0
# 22406      8.0  10684      9.0  29.5   1.6    1.10    P      2.0    P -57.0
#
# ...

# %%
df[ (df.lsat == 29) & (df.tier == 2) ]
# Out:
#        decile1b  decile3     ID  decile1  sex  race  cluster  lsat  ugpa  \
# 1           5.0      4.0      3      5.0  1.0   7.0      2.0  29.0   3.5
# 84          6.0      7.0   1194      6.0  2.0   7.0      2.0  29.0   3.5
# 256         9.0      8.0   3772      9.0  2.0   7.0      2.0  29.0   3.5
# 496         5.0      6.0   7125      6.0  2.0   7.0      2.0  29.0   3.5
# 704         4.0      7.0  10139      5.0  1.0   7.0      2.0  29.0   3.5
# ...         ...      ...    ...      ...  ...   ...      ...   ...   ...
# 21548       1.0      7.0   3842      1.0  2.0   2.0      2.0  29.0   2.5
# 21920       1.0      2.0  23284      1.0  1.0   7.0      2.0  29.0   2.5
# 21966       4.0      5.0  25701      4.0  2.0   7.0      2.0  29.0   2.5
# 22158       6.0      3.0  19872      6.0  1.0   7.0      2.0  29.0   2.3
# 22177       1.0      1.0  21783      2.0  2.0   2.0      2.0  29.0   2.3
#
#        zfygpa  ...  hisp pass_bar                bar bar_passed  tier  \
# ...

# %%
df[ (df.sex == 2) & (df.cluster == 3) | (df.ugpa == 3.5)]
# Out:
#        decile1b  decile3     ID  decile1  sex  race  cluster  lsat  ugpa  \
# 0          10.0     10.0      2     10.0  1.0   7.0      1.0  44.0   3.5
# 1           5.0      4.0      3      5.0  1.0   7.0      2.0  29.0   3.5
# 2           3.0      2.0     36      3.0  2.0   7.0      3.0  36.0   3.5
# 3           7.0      4.0     52      7.0  2.0   7.0      3.0  39.0   3.5
# 4           9.0      8.0     55      9.0  2.0   7.0      4.0  48.0   3.5
# ...         ...      ...    ...      ...  ...   ...      ...   ...   ...
# 22385       1.0      2.0  22271      1.0  2.0   7.0      3.0  41.0   1.9
# 22386       2.0      4.0  22727      3.0  2.0   7.0      3.0  35.0   1.9
# 22394       8.0      9.0   2675      8.0  2.0   7.0      3.0  37.0   1.7
# 22404       7.0      8.0  24704      7.0  2.0   3.0      3.0  36.0   1.8
# 22405      10.0     10.0  10000     10.0  2.0   7.0      3.0  44.0   1.5
#
#        zfygpa  ...  hisp pass_bar                bar bar_passed  tier  \
# ...

# %%
# Сортировка
df[ df.sex == 1 ].sort_values( by = ["sex", "cluster", "ugpa"], ascending = [True, False, False] )
# Out:
#        decile1b  decile3     ID  decile1  sex  race  cluster  lsat  ugpa  \
# 13161      10.0     10.0  11119     10.0  1.0   7.0      6.0  34.0   3.9
# 13232      10.0     10.0  13327     10.0  1.0   7.0      6.0  37.0   3.9
# 13362       3.0      3.0  17955      4.0  1.0   7.0      6.0  29.0   3.9
# 13414       8.0      4.0  19768      8.0  1.0   7.0      6.0  29.0   3.9
# 20478       3.0      3.0   2220      4.0  1.0   7.0      6.0  23.0   3.8
# ...         ...      ...    ...      ...  ...   ...      ...   ...   ...
# 20294       NaN      NaN  24202      NaN  1.0   7.0      NaN  32.0   2.6
# 21871       NaN      NaN  20563      NaN  1.0   7.0      NaN  25.0   2.5
# 21977       NaN      NaN  26085      NaN  1.0   8.0      NaN  30.0   2.5
# 8195        NaN      NaN   2322      NaN  1.0   7.0      NaN  33.0   2.4
# 22109       NaN      NaN  14437      NaN  1.0   7.0      NaN  34.0   2.3
#
#        zfygpa  ...  hisp pass_bar                bar bar_passed  tier  \
# ...

# %%
#Группировка данных
df.groupby(["sex"])[["cluster", "ugpa"]].agg( [np.mean, np.min, np.max] )
# Out:
#       cluster                ugpa
#          mean amin amax      mean amin amax
# sex
# 1.0  2.861636  1.0  6.0  3.277417  1.7  3.9
# 2.0  2.782866  1.0  6.0  3.167009  1.5  3.9

# %%
# Выполнить объединение таблиц с различнымы типами присоединения 
lec = pd.read_csv("winequality-red.csv")
lec.head()
merge = pd.merge(df, lec, how='left', left_index=True, right_index=True)
merge.head()
# Out:
#    decile1b  decile3  ID  decile1  sex  race  cluster  lsat  ugpa  zfygpa  \
# 0      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
# 1       5.0      4.0   3      5.0  1.0   7.0      2.0  29.0   3.5   -0.11
# 2       3.0      2.0  36      3.0  2.0   7.0      3.0  36.0   3.5   -0.64
# 3       7.0      4.0  52      7.0  2.0   7.0      3.0  39.0   3.5    0.34
# 4       9.0      8.0  55      9.0  2.0   7.0      4.0  48.0   3.5    1.02
#
#    ...  citric acid residual sugar  chlorides free sulfur dioxide  \
# 0  ...         0.00            1.9      0.076                11.0
# 1  ...         0.00            2.6      0.098                25.0
# 2  ...         0.04            2.3      0.092                15.0
# 3  ...         0.56            1.9      0.075                17.0
# 4  ...         0.00            1.9      0.076                11.0
#
#    total sulfur dioxide density    pH  sulphates  alcohol  quality
# ...

# %%
merge = pd.merge(df, lec, how='left', left_on='race', right_on='fixed acidity')
merge.head()
# Out:
#    decile1b  decile3  ID  decile1  sex  race  cluster  lsat  ugpa  zfygpa  \
# 0      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
# 1      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
# 2      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
# 3      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
# 4      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
#
#    ...  citric acid residual sugar  chlorides free sulfur dioxide  \
# 0  ...         0.05            2.0      0.081                13.0
# 1  ...         0.08            1.8      0.076                 8.0
# 2  ...         0.25            2.0      0.070                 3.0
# 3  ...         0.08            1.8      0.097                22.0
# 4  ...         0.00            2.5      0.068                 7.0
#
#    total sulfur dioxide density    pH  sulphates  alcohol  quality
# ...

# %%
#Конец
